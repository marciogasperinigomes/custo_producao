# %% [markdown]
# ### **PROJETO CUSTOS DE PRODUÇÃO **

# %% [markdown]
# Neste projeto é feita a concatenação de mais de 30 planilhas com doze culturas agrícolas de inverno e verão. Como resultado, temos um único dataframe com a série histórica de todas as culturas analisadas.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Passo 1: importar os pacotes necessários
import os
import pandas as pd
import plotly.express as px

# %%
# Passo 2:  Definir uma variavel para o nome do caminho onde estão as planilhas, ou seja, a pasta onde estão:
path = r'/content/drive/MyDrive/2. Projetos de ciência de dados/Custo Ref. Produção - Tratamento de dados/2. Planilhas de custo por mes e ano '
# obs: o "r" serve para ajustar as barras do endereço a ser buscado, facilitando o trabalho.

# %%
# Passo 3: Definir uma lista de todos os arquivos existentes na pasta especificado e criar um dataframe em branco, onde serão, posteriormente, acomodados os dados de todas as planlhas.
files = os.listdir(path)

df = pd.DataFrame()

display(files)
# Out:
# ['Custo_referencial_abril_2020.xlsx',
#  'Custo_referencial_abril_2021.xlsx',
#  'Custo_referencial_abril_2022.xlsx',
#  'Custo_referencial_outubro_2019.xlsx',
#  'Custo_referencial_outubro_2020.xlsx',
#  'Custo_referencial_outubro_2021.xlsx',
#  'Custo_referencial_abril_2023.xlsx',
#  'Custo_referencial_outubro_2022.xlsx',
#  'Custo_referencial_julho_2019_2022.xlsx',
#  'Custo_referencial_abril_2019.xlsx']

# %%
# Passo 4: Agora, vamos denominar os caminhos específicos de cada um dos arquivos da pasta onde estão todas as planilhas, ou seja, da pasta denominada "path"
# Chamaremos de "files_xlsx" e buscaremos apenas os arquivos com a extensão "xlsx":
files_xslx= [path + '/' + f for f in files if f [-4:] =='xlsx']

print("Arquivos em '", path, "':")

display(files_xslx)
# Out:
# Arquivos em ' /content/drive/MyDrive/2. Projetos de ciência de dados/Custo Ref. Produção - Tratamento de dados/2. Planilhas de custo por mes e ano  ':
# ['/content/drive/MyDrive/2. Projetos de ciência de dados/Custo Ref. Produção - Tratamento de dados/2. Planilhas de custo por mes e ano /Custo_referencial_abril_2020.xlsx',
#  '/content/drive/MyDrive/2. Projetos de ciência de dados/Custo Ref. Produção - Tratamento de dados/2. Planilhas de custo por mes e ano /Custo_referencial_abril_2021.xlsx',
#  '/content/drive/MyDrive/2. Projetos de ciência de dados/Custo Ref. Produção - Tratamento de dados/2. Planilhas de custo por mes e ano /Custo_referencial_abril_2022.xlsx',
#  '/content/drive/MyDrive/2. Projetos de ciência de dados/Custo Ref. Produção - Tratamento de dados/2. Planilhas de custo por mes e ano /Custo_referencial_outubro_2019.xlsx',
#  '/content/drive/MyDrive/2. Projetos de ciência de dados/Custo Ref. Produção - Tratamento de dados/2. Planilhas de custo por mes e ano /Custo_referencial_outubro_2020.xlsx',
#  '/content/drive/MyDrive/2. Projetos de ciência de dados/Custo Ref. Produção - Tratamento de dados/2. Planilhas de custo por mes e ano /Custo_referencial_outubro_2021.xlsx',
#  '/content/drive/MyDrive/2. Projetos de ciência de dados/Custo Ref. Produção - Tratamento de dados/2. Planilhas de custo por mes e ano /Custo_referencial_abril_2023.xlsx',
#  '/content/drive/MyDrive/2. Projetos de ciência de dados/Custo Ref. Produção - Tratamento de dados/2. Planilhas de custo por mes e ano /Custo_referencial_outubro_2022.xlsx',
#  '/content/drive/MyDrive/2. Projetos de ciência de dados/Custo Ref. Produção - Tratamento de dados/2. Planilhas de custo por mes e ano /Custo_referencial_julho_2019_2022.xlsx',
#  '/content/drive/MyDrive/2. Projetos de ciência de dados/Custo Ref. Produção - Tratamento de dados/2. Planilhas de custo por mes e ano /Custo_referencial_abril_2019.xlsx']

# %%
# Passo 5: Agora, vamos criar uma variavel chamada "data", que irá fazer a leitura, em excel, de cada uma dos arquivos chamados files_xlsx.
# Iremos ler apenas os arquivos que possuem "Custo_referencial" no nome:

for f in files_xslx:
  if "Custo_referencial" in f:
    data = pd.read_excel(f)
    display(data)
    # Na sequência, iremos concatenar as planilhas em excel, denominadas "data", com o DataFrame (df) que foi criado anteriormente e está pronto para receber os dados:
    # Aqui, ordenamos a tabela pela coluna dat_ano, de forma decrescente:
    df = pd.concat([df,data]).sort_values(by="nom_produto", ascending=True)
# Out:
#      dat_ano dat_mes           nom_produto chave_operacao  cod_tipo_registro  \
# 0       2020   Abril                  Alho            Não                  1
# 1       2020   Abril                  Alho            Não                  1
# 2       2020   Abril                  Alho            Não                  1
# 3       2020   Abril                  Alho            Não                  1
# 4       2020   Abril                  Alho            Não                  1
# ..       ...     ...                   ...            ...                ...
# 331     2020   Abril  Aveia preta + azevem            Não                  4
# 332     2020   Abril  Aveia preta + azevem            Sim                  2
# 333     2020   Abril  Aveia preta + azevem            Sim                  2
# 334     2020   Abril  Aveia preta + azevem            Sim                  2
# 335     2020   Abril  Aveia preta + azevem            Sim                  2
#
#             dsc_registro                                       dsc_formula  \
# 0    Para cálculo do COE                                     Não se aplica
# 1    Para cálculo do COE                                     Não se aplica
# 2    Para cálculo do COE                                     Não se aplica
# 3    Para cálculo do COE                                     Não se aplica
# 4    Para cálculo do COE                                     Não se aplica
# ..                   ...                                               ...
# 331        Receita Bruta                                     Não se aplica
# 332            Resultado                margem bruta (receita bruta - coe)
# 333            Resultado          Lucro Operacional (Receita Bruta  - COT)
# 334            Resultado  Produtividade de Nivelamento (sacas) (COT/preço)
# 335            Resultado  Preço de Nivelamento (R$) (COT/produt. em sacas)
#
#                                       nom_grupo_custo  \
# 0                                             Insumos
# 1                                             Insumos
# 2                                             Insumos
# 3                                             Insumos
# 4                                         Mão de obra
# ..                                                ...
# 331                                Receita Bruta (RB)
# 332                                 Margem Bruta (MB)
# 333                            Lucro Operacional (LO)
# 334  Produtividade de Nivelamento (sacas) (COT/preço)
# 335  Preço de Nivelamento (R$) (COT/produt. em sacas)
#
#                                    nom_subgrupo_custo      val_r_ha
# 0                                            Sementes  15600.000000
# 1                                       Fertilizantes   3886.844000
# 2                                         Agrotóxicos   4177.193839
# 3                                              Outros    362.500000
# 4                       Mão de obra - preparo do solo   1258.547500
# ..                                                ...           ...
# 331                                Receita Bruta (RB)      0.000000
# 332                                 Margem Bruta (MB)      0.000000
# 333                            Lucro Operacional (LO)      0.000000
# 334  Produtividade de Nivelamento (sacas) (COT/preço)      0.000000
# 335  Preço de Nivelamento (R$) (COT/produt. em sacas)      0.000000
#
# [336 rows x 10 columns]
#      dat_ano dat_mes           nom_produto chave_operacao  cod_tipo_registro  \
# 0       2021   Abril                  Alho            Não                  1
# 1       2021   Abril                  Alho            Não                  1
# 2       2021   Abril                  Alho            Não                  1
# 3       2021   Abril                  Alho            Não                  1
# 4       2021   Abril                  Alho            Não                  1
# ..       ...     ...                   ...            ...                ...
# 359     2021   Abril  Aveia preta + azevem            Não                  4
# 360     2021   Abril  Aveia preta + azevem            Sim                  2
# 361     2021   Abril  Aveia preta + azevem            Sim                  2
# 362     2021   Abril  Aveia preta + azevem            Sim                  2
# 363     2021   Abril  Aveia preta + azevem            Sim                  2
#
#             dsc_registro                                       dsc_formula  \
# 0    Para cálculo do COE                                     Não se aplica
# 1    Para cálculo do COE                                     Não se aplica
# 2    Para cálculo do COE                                     Não se aplica
# 3    Para cálculo do COE                                     Não se aplica
# 4    Para cálculo do COE                                     Não se aplica
# ..                   ...                                               ...
# 359        Receita Bruta                                     Não se aplica
# 360            Resultado                margem bruta (receita bruta - coe)
# 361            Resultado          Lucro Operacional (Receita Bruta  - COT)
# 362            Resultado  Produtividade de Nivelamento (sacas) (COT/preço)
# 363            Resultado  Preço de Nivelamento (R$) (COT/produt. em sacas)
#
#                                       nom_grupo_custo  \
# 0                                             Insumos
# 1                                             Insumos
# 2                                             Insumos
# 3                                             Insumos
# 4                                         Mão de obra
# ..                                                ...
# 359                                Receita Bruta (RB)
# 360                                 Margem Bruta (MB)
# 361                            Lucro Operacional (LO)
# 362  Produtividade de Nivelamento (sacas) (COT/preço)
# 363  Preço de Nivelamento (R$) (COT/produt. em sacas)
#
#                                    nom_subgrupo_custo  val_r_ha
# 0                                            Sementes  15600.00
# 1                                       Fertilizantes   6081.83
# 2                                         Agrotóxicos   4623.38
# 3                                              Outros    318.27
# 4                       Mão de obra - preparo do solo   1315.25
# ..                                                ...       ...
# 359                                Receita Bruta (RB)      0.00
# 360                                 Margem Bruta (MB)      0.00
# 361                            Lucro Operacional (LO)      0.00
# 362  Produtividade de Nivelamento (sacas) (COT/preço)      0.00
# 363  Preço de Nivelamento (R$) (COT/produt. em sacas)      0.00
#
# [364 rows x 10 columns]
#      dat_ano dat_mes           nom_produto chave_operacao  cod_tipo_registro  \
# 0       2022   Abril                  Alho            Não                  1
# 1       2022   Abril                  Alho            Não                  1
# 2       2022   Abril                  Alho            Não                  1
# 3       2022   Abril                  Alho            Não                  1
# 4       2022   Abril                  Alho            Não                  1
# ..       ...     ...                   ...            ...                ...
# 359     2022   Abril  Aveia preta + azevem            Não                  4
# 360     2022   Abril  Aveia preta + azevem            Sim                  2
# 361     2022   Abril  Aveia preta + azevem            Sim                  2
# 362     2022   Abril  Aveia preta + azevem            Sim                  2
# 363     2022   Abril  Aveia preta + azevem            Sim                  2
#
#             dsc_registro                                       dsc_formula  \
# 0    Para cálculo do COE                                     Não se aplica
# 1    Para cálculo do COE                                     Não se aplica
# 2    Para cálculo do COE                                     Não se aplica
# 3    Para cálculo do COE                                     Não se aplica
# 4    Para cálculo do COE                                     Não se aplica
# ..                   ...                                               ...
# 359        Receita Bruta                                     Não se aplica
# 360            Resultado                margem bruta (receita bruta - coe)
# 361            Resultado          Lucro Operacional (Receita Bruta  - COT)
# 362            Resultado  Produtividade de Nivelamento (sacas) (COT/preço)
# 363            Resultado  Preço de Nivelamento (R$) (COT/produt. em sacas)
#
#                                       nom_grupo_custo  \
# 0                                             Insumos
# 1                                             Insumos
# 2                                             Insumos
# 3                                             Insumos
# 4                                         Mão de obra
# ..                                                ...
# 359                                Receita Bruta (RB)
# 360                                 Margem Bruta (MB)
# 361                            Lucro Operacional (LO)
# 362  Produtividade de Nivelamento (sacas) (COT/preço)
# 363  Preço de Nivelamento (R$) (COT/produt. em sacas)
#
#                                    nom_subgrupo_custo  val_r_ha
# 0                                            Sementes  20280.00
# 1                                       Fertilizantes   9690.66
# 2                                         Agrotóxicos   4400.87
# 3                                              Outros    448.70
# 4                       Mão de obra - preparo do solo   1436.45
# ..                                                ...       ...
# 359                                Receita Bruta (RB)      0.00
# 360                                 Margem Bruta (MB)      0.00
# 361                            Lucro Operacional (LO)      0.00
# 362  Produtividade de Nivelamento (sacas) (COT/preço)      0.00
# 363  Preço de Nivelamento (R$) (COT/produt. em sacas)      0.00
#
# [364 rows x 10 columns]
#      dat_ano  dat_mes           nom_produto chave_operacao  cod_tipo_registro  \
# 0       2019  Outubro                  Alho            Não                  1
# 1       2019  Outubro                  Alho            Não                  1
# 2       2019  Outubro                  Alho            Não                  1
# 3       2019  Outubro                  Alho            Não                  1
# 4       2019  Outubro                  Alho            Não                  1
# ..       ...      ...                   ...            ...                ...
# 331     2019  Outubro  Aveia preta + azevem            Não                  4
# 332     2019  Outubro  Aveia preta + azevem            Sim                  2
# 333     2019  Outubro  Aveia preta + azevem            Sim                  2
# 334     2019  Outubro  Aveia preta + azevem            Sim                  2
# 335     2019  Outubro  Aveia preta + azevem            Sim                  2
#
#             dsc_registro                                       dsc_formula  \
# 0    Para cálculo do COE                                     Não se aplica
# 1    Para cálculo do COE                                     Não se aplica
# 2    Para cálculo do COE                                     Não se aplica
# 3    Para cálculo do COE                                     Não se aplica
# 4    Para cálculo do COE                                     Não se aplica
# ..                   ...                                               ...
# 331        Receita Bruta                                     Não se aplica
# 332            Resultado                margem bruta (receita bruta - coe)
# 333            Resultado          Lucro Operacional (Receita Bruta  - COT)
# 334            Resultado  Produtividade de Nivelamento (sacas) (COT/preço)
# 335            Resultado  Preço de Nivelamento (R$) (COT/produt. em sacas)
#
#                                       nom_grupo_custo  \
# 0                                             Insumos
# 1                                             Insumos
# 2                                             Insumos
# 3                                             Insumos
# 4                                         Mão de obra
# ..                                                ...
# 331                                Receita Bruta (RB)
# 332                                 Margem Bruta (MB)
# 333                            Lucro Operacional (LO)
# 334  Produtividade de Nivelamento (sacas) (COT/preço)
# 335  Preço de Nivelamento (R$) (COT/produt. em sacas)
#
#                                    nom_subgrupo_custo  val_r_ha
# 0                                            Sementes       0.0
# 1                                       Fertilizantes       0.0
# 2                                         Agrotóxicos       0.0
# 3                                              Outros       0.0
# 4                       Mão de obra - preparo do solo       0.0
# ..                                                ...       ...
# 331                                Receita Bruta (RB)       0.0
# 332                                 Margem Bruta (MB)       0.0
# 333                            Lucro Operacional (LO)       0.0
# 334  Produtividade de Nivelamento (sacas) (COT/preço)       0.0
# 335  Preço de Nivelamento (R$) (COT/produt. em sacas)       0.0
#
# [336 rows x 10 columns]
#      dat_ano  dat_mes           nom_produto chave_operacao  cod_tipo_registro  \
# 0       2020  Outubro                  Alho            Não                  1
# 1       2020  Outubro                  Alho            Não                  1
# 2       2020  Outubro                  Alho            Não                  1
# 3       2020  Outubro                  Alho            Não                  1
# 4       2020  Outubro                  Alho            Não                  1
# ..       ...      ...                   ...            ...                ...
# 331     2020  Outubro  Aveia preta + azevem            Não                  4
# 332     2020  Outubro  Aveia preta + azevem            Sim                  2
# 333     2020  Outubro  Aveia preta + azevem            Sim                  2
# 334     2020  Outubro  Aveia preta + azevem            Sim                  2
# 335     2020  Outubro  Aveia preta + azevem            Sim                  2
#
#             dsc_registro                                       dsc_formula  \
# 0    Para cálculo do COE                                     Não se aplica
# 1    Para cálculo do COE                                     Não se aplica
# 2    Para cálculo do COE                                     Não se aplica
# 3    Para cálculo do COE                                     Não se aplica
# 4    Para cálculo do COE                                     Não se aplica
# ..                   ...                                               ...
# 331        Receita Bruta                                     Não se aplica
# 332            Resultado                margem bruta (receita bruta - coe)
# 333            Resultado          Lucro Operacional (Receita Bruta  - COT)
# 334            Resultado  Produtividade de Nivelamento (sacas) (COT/preço)
# 335            Resultado  Preço de Nivelamento (R$) (COT/produt. em sacas)
#
#                                       nom_grupo_custo  \
# 0                                             Insumos
# 1                                             Insumos
# 2                                             Insumos
# 3                                             Insumos
# 4                                         Mão de obra
# ..                                                ...
# 331                                Receita Bruta (RB)
# 332                                 Margem Bruta (MB)
# 333                            Lucro Operacional (LO)
# 334  Produtividade de Nivelamento (sacas) (COT/preço)
# 335  Preço de Nivelamento (R$) (COT/produt. em sacas)
#
#                                    nom_subgrupo_custo      val_r_ha
# 0                                            Sementes  15600.000000
# 1                                       Fertilizantes   4454.341905
# 2                                         Agrotóxicos   4486.488175
# 3                                              Outros    377.725000
# 4                       Mão de obra - preparo do solo   1247.505000
# ..                                                ...           ...
# 331                                Receita Bruta (RB)      0.000000
# 332                                 Margem Bruta (MB)      0.000000
# 333                            Lucro Operacional (LO)      0.000000
# 334  Produtividade de Nivelamento (sacas) (COT/preço)      0.000000
# 335  Preço de Nivelamento (R$) (COT/produt. em sacas)      0.000000
#
# [336 rows x 10 columns]
#      dat_ano  dat_mes           nom_produto chave_operacao  cod_tipo_registro  \
# 0       2021  Outubro                  Alho            Não                  1
# 1       2021  Outubro                  Alho            Não                  1
# 2       2021  Outubro                  Alho            Não                  1
# 3       2021  Outubro                  Alho            Não                  1
# 4       2021  Outubro                  Alho            Não                  1
# ..       ...      ...                   ...            ...                ...
# 359     2021  Outubro  Aveia preta + azevem            Não                  4
# 360     2021  Outubro  Aveia preta + azevem            Sim                  2
# 361     2021  Outubro  Aveia preta + azevem            Sim                  2
# 362     2021  Outubro  Aveia preta + azevem            Sim                  2
# 363     2021  Outubro  Aveia preta + azevem            Sim                  2
#
#             dsc_registro                                       dsc_formula  \
# 0    Para cálculo do COE                                     Não se aplica
# 1    Para cálculo do COE                                     Não se aplica
# 2    Para cálculo do COE                                     Não se aplica
# 3    Para cálculo do COE                                     Não se aplica
# 4    Para cálculo do COE                                     Não se aplica
# ..                   ...                                               ...
# 359        Receita Bruta                                     Não se aplica
# 360            Resultado                margem bruta (receita bruta - coe)
# 361            Resultado          Lucro Operacional (Receita Bruta  - COT)
# 362            Resultado  Produtividade de Nivelamento (sacas) (COT/preço)
# 363            Resultado  Preço de Nivelamento (R$) (COT/produt. em sacas)
#
#                                       nom_grupo_custo  \
# 0                                             Insumos
# 1                                             Insumos
# 2                                             Insumos
# 3                                             Insumos
# 4                                         Mão de obra
# ..                                                ...
# 359                                Receita Bruta (RB)
# 360                                 Margem Bruta (MB)
# 361                            Lucro Operacional (LO)
# 362  Produtividade de Nivelamento (sacas) (COT/preço)
# 363  Preço de Nivelamento (R$) (COT/produt. em sacas)
#
#                                    nom_subgrupo_custo      val_r_ha
# 0                                            Sementes  15600.000000
# 1                                       Fertilizantes   7997.865833
# 2                                         Agrotóxicos   3806.822167
# 3                                              Outros    428.300000
# 4                       Mão de obra - preparo do solo   1434.000000
# ..                                                ...           ...
# 359                                Receita Bruta (RB)      0.000000
# 360                                 Margem Bruta (MB)      0.000000
# 361                            Lucro Operacional (LO)      0.000000
# 362  Produtividade de Nivelamento (sacas) (COT/preço)      0.000000
# 363  Preço de Nivelamento (R$) (COT/produt. em sacas)      0.000000
#
# [364 rows x 10 columns]
#      dat_ano dat_mes           nom_produto chave_operacao  cod_tipo_registro  \
# 0       2023   Abril                  Alho            Não                  1
# 1       2023   Abril                  Alho            Não                  1
# 2       2023   Abril                  Alho            Não                  1
# 3       2023   Abril                  Alho            Não                  1
# 4       2023   Abril                  Alho            Não                  1
# ..       ...     ...                   ...            ...                ...
# 359     2023   Abril  Aveia preta + azevem            Não                  4
# 360     2023   Abril  Aveia preta + azevem            Sim                  2
# 361     2023   Abril  Aveia preta + azevem            Sim                  2
# 362     2023   Abril  Aveia preta + azevem            Sim                  2
# 363     2023   Abril  Aveia preta + azevem            Sim                  2
#
#             dsc_registro                                       dsc_formula  \
# 0    Para cálculo do COE                                     Não se aplica
# 1    Para cálculo do COE                                     Não se aplica
# 2    Para cálculo do COE                                     Não se aplica
# 3    Para cálculo do COE                                     Não se aplica
# 4    Para cálculo do COE                                     Não se aplica
# ..                   ...                                               ...
# 359        Receita Bruta                                     Não se aplica
# 360            Resultado                margem bruta (receita bruta - coe)
# 361            Resultado          Lucro Operacional (Receita Bruta  - COT)
# 362            Resultado  Produtividade de Nivelamento (sacas) (COT/preço)
# 363            Resultado  Preço de Nivelamento (R$) (COT/produt. em sacas)
#
#                                       nom_grupo_custo  \
# 0                                             Insumos
# 1                                             Insumos
# 2                                             Insumos
# 3                                             Insumos
# 4                                         Mão de obra
# ..                                                ...
# 359                                Receita Bruta (RB)
# 360                                 Margem Bruta (MB)
# 361                            Lucro Operacional (LO)
# 362  Produtividade de Nivelamento (sacas) (COT/preço)
# 363  Preço de Nivelamento (R$) (COT/produt. em sacas)
#
#                                    nom_subgrupo_custo      val_r_ha
# 0                                            Sementes  20280.000000
# 1                                       Fertilizantes   6289.353543
# 2                                         Agrotóxicos   4621.446714
# 3                                              Outros    529.050000
# 4                       Mão de obra - preparo do solo   1569.452500
# ..                                                ...           ...
# 359                                Receita Bruta (RB)      0.000000
# 360                                 Margem Bruta (MB)      0.000000
# 361                            Lucro Operacional (LO)      0.000000
# 362  Produtividade de Nivelamento (sacas) (COT/preço)      0.000000
# 363  Preço de Nivelamento (R$) (COT/produt. em sacas)      0.000000
#
# [364 rows x 10 columns]
#      dat_ano  dat_mes           nom_produto chave_operacao  cod_tipo_registro  \
# 0       2022  Outubro                  Alho            Não                  1
# 1       2022  Outubro                  Alho            Não                  1
# 2       2022  Outubro                  Alho            Não                  1
# 3       2022  Outubro                  Alho            Não                  1
# 4       2022  Outubro                  Alho            Não                  1
# ..       ...      ...                   ...            ...                ...
# 359     2022  Outubro  Aveia preta + azevem            Não                  4
# 360     2022  Outubro  Aveia preta + azevem            Sim                  2
# 361     2022  Outubro  Aveia preta + azevem            Sim                  2
# 362     2022  Outubro  Aveia preta + azevem            Sim                  2
# 363     2022  Outubro  Aveia preta + azevem            Sim                  2
#
#             dsc_registro                                       dsc_formula  \
# 0    Para cálculo do COE                                     Não se aplica
# 1    Para cálculo do COE                                     Não se aplica
# 2    Para cálculo do COE                                     Não se aplica
# 3    Para cálculo do COE                                     Não se aplica
# 4    Para cálculo do COE                                     Não se aplica
# ..                   ...                                               ...
# 359        Receita Bruta                                     Não se aplica
# 360            Resultado                margem bruta (receita bruta - coe)
# 361            Resultado          Lucro Operacional (Receita Bruta  - COT)
# 362            Resultado  Produtividade de Nivelamento (sacas) (COT/preço)
# 363            Resultado  Preço de Nivelamento (R$) (COT/produt. em sacas)
#
#                                       nom_grupo_custo  \
# 0                                             Insumos
# 1                                             Insumos
# 2                                             Insumos
# 3                                             Insumos
# 4                                         Mão de obra
# ..                                                ...
# 359                                Receita Bruta (RB)
# 360                                 Margem Bruta (MB)
# 361                            Lucro Operacional (LO)
# 362  Produtividade de Nivelamento (sacas) (COT/preço)
# 363  Preço de Nivelamento (R$) (COT/produt. em sacas)
#
#                                    nom_subgrupo_custo  val_r_ha
# 0                                            Sementes  20280.00
# 1                                       Fertilizantes   8120.61
# 2                                         Agrotóxicos   4688.70
# 3                                              Outros    527.79
# 4                       Mão de obra - preparo do solo   1530.90
# ..                                                ...       ...
# 359                                Receita Bruta (RB)      0.00
# 360                                 Margem Bruta (MB)      0.00
# 361                            Lucro Operacional (LO)      0.00
# 362  Produtividade de Nivelamento (sacas) (COT/preço)      0.00
# 363  Preço de Nivelamento (R$) (COT/produt. em sacas)      0.00
#
# [364 rows x 10 columns]
#       dat_ano dat_mes nom_produto chave_operacao  cod_tipo_registro  \
# 0        2019   Julho       Arroz            Não                  1
# 1        2019   Julho       Arroz            Não                  1
# 2        2019   Julho       Arroz            Não                  1
# 3        2019   Julho       Arroz            Não                  1
# 4        2019   Julho       Arroz            Não                  1
# ...       ...     ...         ...            ...                ...
# 1451     2022   Julho      Cebola            Não                  4
# 1452     2022   Julho      Cebola            Sim                  2
# 1453     2022   Julho      Cebola            Sim                  2
# 1454     2022   Julho      Cebola            Sim                  2
# 1455     2022   Julho      Cebola            Sim                  2
#
#              dsc_registro                                       dsc_formula  \
# 0     Para cálculo do COE                                     Não se aplica
# 1     Para cálculo do COE                                     Não se aplica
# 2     Para cálculo do COE                                     Não se aplica
# 3     Para cálculo do COE                                     Não se aplica
# 4     Para cálculo do COE                                     Não se aplica
# ...                   ...                                               ...
# 1451        Receita Bruta                                     Não se aplica
# 1452            Resultado                margem bruta (receita bruta - coe)
# 1453            Resultado          Lucro Operacional (Receita Bruta  - COT)
# 1454            Resultado  Produtividade de Nivelamento (sacas) (COT/preço)
# 1455            Resultado  Preço de Nivelamento (R$) (COT/produt. em sacas)
#
#                                        nom_grupo_custo  \
# 0                                              Insumos
# 1                                              Insumos
# 2                                              Insumos
# 3                                              Insumos
# 4                                          Mão de obra
# ...                                                ...
# 1451                                Receita Bruta (RB)
# 1452                                 Margem Bruta (MB)
# 1453                            Lucro Operacional (LO)
# 1454  Produtividade de Nivelamento (sacas) (COT/preço)
# 1455  Preço de Nivelamento (R$) (COT/produt. em sacas)
#
#                                     nom_subgrupo_custo  val_r_ha
# 0                                             Sementes    242.71
# 1                                        Fertilizantes    848.51
# 2                                          Agrotóxicos    282.76
# 3                                               Outros      0.00
# 4                        Mão de obra - preparo do solo    257.33
# ...                                                ...       ...
# 1451                                Receita Bruta (RB)  45000.00
# 1452                                 Margem Bruta (MB)   3328.08
# 1453                            Lucro Operacional (LO)   1323.89
# 1454  Produtividade de Nivelamento (sacas) (COT/preço)   1213.23
# 1455  Preço de Nivelamento (R$) (COT/produt. em sacas)     34.94
#
# [1456 rows x 10 columns]
#      dat_ano dat_mes           nom_produto chave_operacao  cod_tipo_registro  \
# 0       2019   Abril                  Alho            Não                  1
# 1       2019   Abril                  Alho            Não                  1
# 2       2019   Abril                  Alho            Não                  1
# 3       2019   Abril                  Alho            Não                  1
# 4       2019   Abril                  Alho            Não                  1
# ..       ...     ...                   ...            ...                ...
# 331     2019   Abril  Aveia preta + azevem            Não                  4
# 332     2019   Abril  Aveia preta + azevem            Sim                  2
# 333     2019   Abril  Aveia preta + azevem            Sim                  2
# 334     2019   Abril  Aveia preta + azevem            Sim                  2
# 335     2019   Abril  Aveia preta + azevem            Sim                  2
#
#             dsc_registro                                       dsc_formula  \
# 0    Para cálculo do COE                                     Não se aplica
# 1    Para cálculo do COE                                     Não se aplica
# 2    Para cálculo do COE                                     Não se aplica
# 3    Para cálculo do COE                                     Não se aplica
# 4    Para cálculo do COE                                     Não se aplica
# ..                   ...                                               ...
# 331        Receita Bruta                                     Não se aplica
# 332            Resultado                margem bruta (receita bruta - coe)
# 333            Resultado          Lucro Operacional (Receita Bruta  - COT)
# 334            Resultado  Produtividade de Nivelamento (sacas) (COT/preço)
# 335            Resultado  Preço de Nivelamento (R$) (COT/produt. em sacas)
#
#                                       nom_grupo_custo  \
# 0                                             Insumos
# 1                                             Insumos
# 2                                             Insumos
# 3                                             Insumos
# 4                                         Mão de obra
# ..                                                ...
# 331                                Receita Bruta (RB)
# 332                                 Margem Bruta (MB)
# 333                            Lucro Operacional (LO)
# 334  Produtividade de Nivelamento (sacas) (COT/preço)
# 335  Preço de Nivelamento (R$) (COT/produt. em sacas)
#
#                                    nom_subgrupo_custo  val_r_ha
# 0                                            Sementes       0.0
# 1                                       Fertilizantes       0.0
# 2                                         Agrotóxicos       0.0
# 3                                              Outros       0.0
# 4                       Mão de obra - preparo do solo       0.0
# ..                                                ...       ...
# 331                                Receita Bruta (RB)       0.0
# 332                                 Margem Bruta (MB)       0.0
# 333                            Lucro Operacional (LO)       0.0
# 334  Produtividade de Nivelamento (sacas) (COT/preço)       0.0
# 335  Preço de Nivelamento (R$) (COT/produt. em sacas)       0.0
#
# [336 rows x 10 columns]

# %%
# Passo 6: Agora, vamos plotar a nova tabela df, que acomoda todos os dados de cada uma das planihas.
display(df)
# Out:
#       dat_ano  dat_mes               nom_produto chave_operacao  \
# 0        2020    Abril                      Alho            Não
# 19       2019  Outubro                      Alho            Não
# 20       2019  Outubro                      Alho            Sim
# 0        2022  Outubro                      Alho            Não
# 11       2023    Abril                      Alho            Não
# ...       ...      ...                       ...            ...
# 1201     2021    Julho  Trigo (média tecnologia)            Sim
# 1200     2021    Julho  Trigo (média tecnologia)            Sim
# 1199     2021    Julho  Trigo (média tecnologia)            Não
# 1197     2021    Julho  Trigo (média tecnologia)            Não
# 280      2021  Outubro  Trigo (média tecnologia)            Não
#
#       cod_tipo_registro          dsc_registro  \
# 0                     1   Para cálculo do COE
# 19                    1   Para cálculo do COE
# 20                    2             Resultado
# 0                     1   Para cálculo do COE
# 11                    1   Para cálculo do COE
# ...                 ...                   ...
# 1201                  2             Resultado
# 1200                  2             Resultado
# 1199                  4         Receita Bruta
# 1197                  3  Para cálculo do  COT
# 280                   1   Para cálculo do COE
#
#                                             dsc_formula  \
# 0                                         Não se aplica
# 19                                        Não se aplica
# 20    COE = soma (todos tipo registro = para cáculo ...
# 0                                         Não se aplica
# 11                                        Não se aplica
# ...                                                 ...
# 1201           Lucro Operacional (Receita Bruta  - COT)
# 1200                 margem bruta (receita bruta - coe)
# 1199                                      Não se aplica
# 1197                                      Não se aplica
# 280                                       Não se aplica
#
#                       nom_grupo_custo                     nom_subgrupo_custo  \
# 0                             Insumos                               Sementes
# 19                       Arrendamento                           Arrendamento
# 20    Custo Operacional Efetivo (COE)        Custo Operacional Efetivo (COE)
# 0                             Insumos                               Sementes
# 11                 Serviços mecânicos  Serviços mecânicos - tratos culturais
# ...                               ...                                    ...
# 1201           Lucro Operacional (LO)                 Lucro Operacional (LO)
# 1200                Margem Bruta (MB)                      Margem Bruta (MB)
# 1199               Receita Bruta (RB)                     Receita Bruta (RB)
# 1197                      Depreciação                            Depreciação
# 280                           Insumos                               Sementes
#
#           val_r_ha
# 0     15600.000000
# 19        0.000000
# 20        0.000000
# 0     20280.000000
# 11     5117.083205
# ...            ...
# 1201    331.710000
# 1200    649.600000
# 1199   4848.000000
# 1197    317.890000
# 280     550.787500
#
# [4620 rows x 10 columns]

# %%
import datetime
#Por último, iremos adicionar uma coluna chamada "data", em formato data no df:
df['dat_ano'] = df['dat_ano'].astype(str)
df['dat_mes'] = df['dat_mes'].astype(str)
df['data'] = '01/'+ df['dat_mes'] + '/' + df['dat_ano']

display(df)
# Out:
#      dat_ano  dat_mes               nom_produto chave_operacao  \
# 0       2020    Abril                      Alho            Não
# 19      2019  Outubro                      Alho            Não
# 20      2019  Outubro                      Alho            Sim
# 0       2022  Outubro                      Alho            Não
# 11      2023    Abril                      Alho            Não
# ...      ...      ...                       ...            ...
# 1201    2021    Julho  Trigo (média tecnologia)            Sim
# 1200    2021    Julho  Trigo (média tecnologia)            Sim
# 1199    2021    Julho  Trigo (média tecnologia)            Não
# 1197    2021    Julho  Trigo (média tecnologia)            Não
# 280     2021  Outubro  Trigo (média tecnologia)            Não
#
#       cod_tipo_registro          dsc_registro  \
# 0                     1   Para cálculo do COE
# 19                    1   Para cálculo do COE
# 20                    2             Resultado
# 0                     1   Para cálculo do COE
# 11                    1   Para cálculo do COE
# ...                 ...                   ...
# 1201                  2             Resultado
# 1200                  2             Resultado
# 1199                  4         Receita Bruta
# 1197                  3  Para cálculo do  COT
# 280                   1   Para cálculo do COE
#
#                                             dsc_formula  \
# 0                                         Não se aplica
# 19                                        Não se aplica
# 20    COE = soma (todos tipo registro = para cáculo ...
# 0                                         Não se aplica
# 11                                        Não se aplica
# ...                                                 ...
# 1201           Lucro Operacional (Receita Bruta  - COT)
# 1200                 margem bruta (receita bruta - coe)
# 1199                                      Não se aplica
# 1197                                      Não se aplica
# 280                                       Não se aplica
#
#                       nom_grupo_custo                     nom_subgrupo_custo  \
# 0                             Insumos                               Sementes
# 19                       Arrendamento                           Arrendamento
# 20    Custo Operacional Efetivo (COE)        Custo Operacional Efetivo (COE)
# 0                             Insumos                               Sementes
# 11                 Serviços mecânicos  Serviços mecânicos - tratos culturais
# ...                               ...                                    ...
# 1201           Lucro Operacional (LO)                 Lucro Operacional (LO)
# 1200                Margem Bruta (MB)                      Margem Bruta (MB)
# 1199               Receita Bruta (RB)                     Receita Bruta (RB)
# 1197                      Depreciação                            Depreciação
# 280                           Insumos                               Sementes
#
#           val_r_ha             data
# 0     15600.000000    01/Abril/2020
# 19        0.000000  01/Outubro/2019
# 20        0.000000  01/Outubro/2019
# 0     20280.000000  01/Outubro/2022
# 11     5117.083205    01/Abril/2023
# ...            ...              ...
# 1201    331.710000    01/Julho/2021
# 1200    649.600000    01/Julho/2021
# 1199   4848.000000    01/Julho/2021
# 1197    317.890000    01/Julho/2021
# 280     550.787500  01/Outubro/2021
#
# [4620 rows x 11 columns]

# %%
# Passo 7: Exportar df para excel:
df.to_excel('Base_custo_referencial_v2.xlsx')
